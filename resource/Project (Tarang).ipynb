# %%
# Ojective

# %%
# Question

# %%
# Codes to get the data from API

# %%
# Growth Stock Definition (Adrian)
# Generally there're a couple of factors we use to determine whether a stock is a growth stock or not. 
# Sales Growth: Growing faster than the average, 10% increase in sales YOY
# Debt Level: Generally decreases over the years
# Do not pay dividends or pay very little, focus on reinvesting into the company for more growth
# Higher than normal P/E ratio
# Usually in Tech in today's environment

# %%
# Google (Tarang)
import numpy as np
import pandas as pd
import os
import alpaca_trade_api as tradeapi
import datetime as dt
import pytz
from pathlib import Path
import hvplot.pandas
from sklearn.linear_model import LinearRegression
# %matplotlib inline

from dotenv import load_dotenv
load_dotenv()

# Set Alpaca API key and secret
alpaca_api_key = os.getenv('ALPACA_API_KEY')
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")


api = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version = "v2"
)

ticker_1 = "GOOGL"

# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 3 years from Today
start_date = pd.Timestamp("2012-07-04", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2022-07-03", tz="America/New_York").isoformat()

# Get 3 years worth of historical data for GOOGL
google_df = api.get_bars(
    ticker_1,
    timeframe,
    start=start_date,
    end=end_date
).df

google_df = google_df.drop(columns=['open','high','low','volume','trade_count','vwap'])
google_df.index = google_df.index.date 
google_df.tail()
# Out:
#               close
# 2022-06-27  2316.67
# 2022-06-28  2240.15
# 2022-06-29  2234.03
# 2022-06-30  2179.26
# 2022-07-01  2174.75

# %%
# Amazon (Tarang)
# Set the ticker
ticker_2 = "AMZN"

# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 7
start_date = pd.Timestamp("2012-07-04", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2022-07-03", tz="America/New_York").isoformat()

# Get 3 years worth of historical data for Amazon
amazon_df = api.get_bars(
    ticker_2,
    timeframe,
    start=start_date,
    end=end_date
).df
amazon_df = amazon_df.drop(columns=['open','high','low','volume','trade_count','vwap'])
amazon_df.index = amazon_df.index.date 


amazon_df.tail()
# Out:
#              close
# 2022-06-27  113.22
# 2022-06-28  107.40
# 2022-06-29  108.92
# 2022-06-30  106.21
# 2022-07-01  109.56

# %%
# Dividend Stock Definition (Adrian)
# Offers regular and steady income (monthly, quarterly, semi-annual, annual) in the form of dividends
# Usually less volatility, not much growth
# Established Player in the market
# Good Dividend stock have moderate income growth every year and a track record of never breaking it

# Graph idea
# Show graph as proofs that there shouldn't be too much volatility
# Graph that measures beta vs Growth stock

# %%
# Embridge (Eric)

# Set the ticker
ticker_4 = "ENB"

# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 3 years from Today
start_date = pd.Timestamp("2012-07-04", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2022-07-03", tz="America/New_York").isoformat()

# Get 3 years worth of historical data for GOOGL
enbridge_df = api.get_bars(
    ticker_4,
    timeframe,
    start=start_date,
    end=end_date
).df

enbridge_df = enbridge_df.drop(columns=['open','high','low','volume','trade_count','vwap'])
enbridge_df.index = enbridge_df.index.date 



enbridge_df.head()
# Out:
#             close
# 2015-12-01  36.09
# 2015-12-02  35.39
# 2015-12-03  34.36
# 2015-12-04  33.71
# 2015-12-07  31.02

# %%
enbridge_df.plot()
# Out:
# <AxesSubplot:>

# %%
# Cola (Eric)
# Set the ticker
ticker_5 = "KO"

# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 3 years from Today
start_date = pd.Timestamp("2012-07-04", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2022-07-03", tz="America/New_York").isoformat()

# Get 3 years worth of historical data for GOOGL
cola_df = api.get_bars(
    ticker_5,
    timeframe,
    start=start_date,
    end=end_date
).df

cola_df = cola_df.drop(columns=['open','high','low','volume','trade_count','vwap'])
cola_df.index = cola_df.index.date 

cola_df.head()
# Out:
#             close
# 2015-12-01  42.89
# 2015-12-02  42.77
# 2015-12-03  42.46
# 2015-12-04  43.29
# 2015-12-07  43.20

# %%
cola_df.plot()
# Out:
# <AxesSubplot:>

# %%
# Blue chip Definition (Adrian)

# Well established
# Large Market Cap
# Part of Market index

# %%
# TD (Saiful)
# Set the ticker
ticker_6 = "TD"

# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 3 years from Today
start_date = pd.Timestamp("2012-07-04", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2022-07-03", tz="America/New_York").isoformat()

# Get 3 years worth of historical data for TD
td_df = api.get_bars(
    ticker_6,
    timeframe,
    start=start_date,
    end=end_date
).df

td_df = td_df.drop(columns=['open','high','low','volume','trade_count','vwap'])
td_df.index = td_df.index.date 




td_df.tail()
# Out:
#             close
# 2022-06-27  65.83
# 2022-06-28  65.81
# 2022-06-29  65.76
# 2022-06-30  65.58
# 2022-07-01  66.22

# %%
# RBC (Saiful)

# Set the ticker
ticker_7 = "RY"

# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 7 years
start_date = pd.Timestamp("2012-07-04", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2022-07-03", tz="America/New_York").isoformat()

# Get 7 years worth of historical data for RBC
rbc_df = api.get_bars(
    ticker_7,
    timeframe,
    start=start_date,
    end=end_date
).df

rbc_df = rbc_df.drop(columns=['open','high','low','volume','trade_count','vwap'])
rbc_df.index = rbc_df.index.date 

rbc_df.tail()
# Out:
#             close
# 2022-06-27  96.86
# 2022-06-28  97.31
# 2022-06-29  97.68
# 2022-06-30  96.82
# 2022-07-01  97.45

# %%
# TD (Saiful)
# Set the ticker
ticker_8 = "VOO"

# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 3 years from Today
start_date = pd.Timestamp("2012-07-04", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2022-07-03", tz="America/New_York").isoformat()

# Get 3 years worth of historical data for TD
spy_df = api.get_bars(
    ticker_8,
    timeframe,
    start=start_date,
    end=end_date
).df


spy_df = spy_df.drop(columns=['open','high','low','volume','trade_count','vwap'])
spy_df.index = spy_df.index.date 




spy_df.tail()
# Out:
#              close
# 2022-06-27  358.65
# 2022-06-28  350.90
# 2022-06-29  349.64
# 2022-06-30  346.88
# 2022-07-01  350.44

# %%
# Interest (Time and date) (Changes)

# %%
# Concat the close price of each stocks
growth_stock_df = pd.concat([google_df,amazon_df,spy_df], axis = 'columns', join='inner')


# Reorganize portfolio data by having a column per symbol
growth_stock_df.columns = ['Google', 'Amazon','SPY']
growth_stock_df.head()
# Out:
#             Google  Amazon     SPY
# 2015-12-01  783.79  679.06  193.22
# 2015-12-02  777.85  676.01  191.18
# 2015-12-03  768.20  666.25  188.46
# 2015-12-04  779.21  672.64  192.16
# 2015-12-07  772.99  669.83  190.95

# %%
# Concat the close price of each stocks
blue_chip_df = pd.concat([td_df,rbc_df,spy_df], axis='columns', join='inner')


# Reorganize portfolio data by having a column per symbol
blue_chip_df.columns = ['TD Bank', 'RBC','SPY']
blue_chip_df.head()
# Out:
#             TD Bank    RBC     SPY
# 2015-12-01    41.36  57.59  193.22
# 2015-12-02    41.19  57.57  191.18
# 2015-12-03    40.64  57.20  188.46
# 2015-12-04    41.02  57.32  192.16
# 2015-12-07    39.98  55.80  190.95

# %%
# Concat the close price of each stocks
dividend_stock_df = pd.concat([enbridge_df,cola_df,spy_df], axis = 'columns', join='inner')


# Reorganize portfolio data by having a column per symbol
dividend_stock_df.columns = ['Enbridge', 'Coca Cola','SPY']
dividend_stock_df.head()
# Out:
#             Enbridge  Coca Cola     SPY
# 2015-12-01     36.09      42.89  193.22
# 2015-12-02     35.39      42.77  191.18
# 2015-12-03     34.36      42.46  188.46
# 2015-12-04     33.71      43.29  192.16
# 2015-12-07     31.02      43.20  190.95

# %%
# Combine interest rate at the bottom

# %%
# Convert historical stock prices to daily percent change - Growth Stocks
growth_pct = growth_stock_df.pct_change().dropna()
growth_pct.head()
# Out:
#               Google    Amazon       SPY
# 2015-12-02 -0.007579 -0.004492 -0.010558
# 2015-12-03 -0.012406 -0.014438 -0.014227
# 2015-12-04  0.014332  0.009591  0.019633
# 2015-12-07 -0.007982 -0.004178 -0.006297
# 2015-12-08  0.002781  0.011197 -0.006389

# %%
# Convert historical stock prices to daily percent change - Dividend Stocks
dividend_pct = dividend_stock_df.pct_change().dropna()
dividend_pct.head()
# Out:
#             Enbridge  Coca Cola       SPY
# 2015-12-02 -0.019396  -0.002798 -0.010558
# 2015-12-03 -0.029104  -0.007248 -0.014227
# 2015-12-04 -0.018917   0.019548  0.019633
# 2015-12-07 -0.079798  -0.002079 -0.006297
# 2015-12-08 -0.006447  -0.004398 -0.006389

# %%
# Convert historical stock prices to daily percent change - Blue Chip Stocks
blue_chip_pct = blue_chip_df.pct_change().dropna()
blue_chip_pct.head()
# Out:
#              TD Bank       RBC       SPY
# 2015-12-02 -0.004110 -0.000347 -0.010558
# 2015-12-03 -0.013353 -0.006427 -0.014227
# 2015-12-04  0.009350  0.002098  0.019633
# 2015-12-07 -0.025353 -0.026518 -0.006297
# 2015-12-08 -0.022011 -0.020609 -0.006389

# %%
#Rolling Beta Growth Stock
    ## Calculate covariance of all daily returns of growth stocks vs. SPY
google_covariance = growth_pct["Google"].cov(growth_pct["SPY"])
amazon_covariance = growth_pct["Amazon"].cov(growth_pct["SPY"])

# Calculate variance of all growth stock returns vs. SPY
variance = growth_pct["SPY"].var()


# Display the covariance of each growth stock
print(f"Google covariance: {google_covariance}")
print(f"Amazon covariance: {amazon_covariance}")

# Diplay S&P 500 variance
print(f"SPY variance: {variance}")
# Out:
# Google covariance: 0.00015575277703204222
# Amazon covariance: 0.00014701760951711966
# SPY variance: 0.0001417046391126396

# %%
#Rolling Beta Growth Stock
    ## Calculate beta of all growth stock
google_beta = google_covariance / variance
amazon_beta = amazon_covariance / variance

# Display the beta value of each growth stock
print(f"Google: {google_beta} | Amazon: {amazon_beta}")
# Out:
# Google: 1.0991367537955894 | Amazon: 1.0374932707761022

# %%
#Rolling Beta Growth Stock
    ## Calculate 30-day rolling covariance of growth stocks vs. SPY
rolling_google_covariance = growth_pct["Google"].rolling(window=30).cov(growth_pct["SPY"])
rolling_amazon_covariance = growth_pct["Amazon"].rolling(window=30).cov(growth_pct["SPY"])

# Calculate 30-day rolling variance of SPY
rolling_variance = growth_pct["SPY"].rolling(window=30).var()

# Calculate 30-day rolling beta of growth stocks and plot the data
rolling_google_beta = rolling_google_covariance / rolling_variance
rolling_amazon_beta = rolling_amazon_covariance / rolling_variance

# Set the figure and plot the different growth stock beta values as multiple trends on the same figure
ax = rolling_google_beta.plot(figsize=(20, 10), title="Rolling 30-Day Beta of Growth Stocks")
rolling_amazon_beta.plot(ax=ax)

ax.legend(["Google", "Amazon"])

# %%
#Rolling Beta Dividend Stock
     ## Calculate covariance of all daily returns of dividend stocks vs. SPY
enbridge_covariance = dividend_pct["Enbridge"].cov(growth_pct["SPY"])
cola_covariance = dividend_pct["Coca Cola"].cov(growth_pct["SPY"])

# Calculate variance of all dividend stock returns vs. SPY
variance = growth_pct["SPY"].var()


# Display the covariance of each dividend stock
print(f"Enbridge covariance: {enbridge_covariance}")
print(f"Coca Cola covariance: {cola_covariance}")

# Diplay SPY variance
print(f"SPY variance: {variance}")
# Out:
# Enbridge covariance: 0.0001299373765371909
# Coca Cola covariance: 9.07366355130614e-05
# SPY variance: 0.0001417046391126396

# %%
#Rolling Beta Dividend Stock
    ## Calculate beta of all dividend stock
enbridge_beta = enbridge_covariance / variance
cola_beta = cola_covariance / variance

    ## Display the beta value of each dividend stock
print(f"Enbridge: {enbridge_beta} | Coca Cola: {cola_beta}")
# Out:
# Enbridge: 0.9169592283701099 | Coca Cola: 0.640322265250157

# %%
#Rolling Beta Dividend Stock
    ## Calculate 30-day rolling covariance of dividend stocks vs. SPY
rolling_enbridge_covariance = dividend_pct["Enbridge"].rolling(window=30).cov(dividend_pct["SPY"])
rolling_cola_covariance = dividend_pct["Coca Cola"].rolling(window=30).cov(dividend_pct["SPY"])

    ## Calculate 30-day rolling variance of SPY
rolling_variance = dividend_pct["SPY"].rolling(window=30).var()

    ## Calculate 30-day rolling beta of dividend stocks and plot the data
rolling_enbridge_beta = rolling_enbridge_covariance / rolling_variance
rolling_cola_beta = rolling_cola_covariance / rolling_variance

    ## Set the figure and plot the different dividend stock beta values as multiple trends on the same figure
ax = rolling_enbridge_beta.plot(figsize=(20, 10), title="Rolling 30-Day Beta of Dividend Stocks")
rolling_cola_beta.plot(ax=ax)

ax.legend(["Enbridge", "Coca Cola"])

# %%
#Rolling Beta Blue Chip Stock
    ## Calculate 30-day rolling covariance of blue chip stocks vs. SPY
rolling_td_covariance = blue_chip_pct["TD Bank"].rolling(window=30).cov(blue_chip_pct["SPY"])
rolling_rbc_covariance = blue_chip_pct["RBC"].rolling(window=30).cov(blue_chip_pct["SPY"])

    ## Calculate 30-day rolling variance of SPY
rolling_variance = blue_chip_pct["SPY"].rolling(window=30).var()

    ## Calculate 30-day rolling beta of blue chip stocks and plot the data
rolling_td_beta = rolling_td_covariance / rolling_variance
rolling_rbc_beta = rolling_rbc_covariance / rolling_variance

    ## Set the figure and plot the different blue chip stock beta values as multiple trends on the same figure
ax = rolling_td_beta.plot(figsize=(20, 10), title="Rolling 30-Day Beta of Blue Chip Stocks")
rolling_rbc_beta.plot(ax=ax)

ax.legend(["TD Bank", "RBC"])

# %%
#Rolling Beta all stocks

rolling_google_covariance = growth_pct["Google"].rolling(window=30).cov(growth_pct["SPY"])
rolling_amazon_covariance = growth_pct["Amazon"].rolling(window=30).cov(growth_pct["SPY"])

enbridge_covariance = dividend_pct["Enbridge"].cov(growth_pct["SPY"])
cola_covariance = dividend_pct["Coca Cola"].cov(growth_pct["SPY"])

rolling_enbridge_covariance = dividend_pct["Enbridge"].rolling(window=30).cov(dividend_pct["SPY"])
rolling_cola_covariance = dividend_pct["Coca Cola"].rolling(window=30).cov(dividend_pct["SPY"])

# Calculate 30-day rolling variance of SPY
rolling_variance = growth_pct["SPY"].rolling(window=30).var()

# Calculate 30-day rolling beta of stocks
rolling_google_beta = rolling_google_covariance / rolling_variance
rolling_amazon_beta = rolling_amazon_covariance / rolling_variance

rolling_enbridge_beta = rolling_enbridge_covariance / rolling_variance
rolling_cola_beta = rolling_cola_covariance / rolling_variance

rolling_td_beta = rolling_td_covariance / rolling_variance
rolling_rbc_beta = rolling_rbc_covariance / rolling_variance

ax = rolling_google_beta.plot(figsize=(20, 10), title="Rolling 30-Day Beta of All Stocks")
rolling_amazon_beta.plot(ax=ax)
rolling_enbridge_beta.plot(ax=ax)
rolling_cola_beta.plot(ax=ax)
rolling_td_beta.plot(ax=ax)
rolling_rbc_beta.plot(ax=ax)


ax.legend(["Google", "Amazon","Enbridge","Coca Cola", "TD Bank", "RBC"])

# %%
# Interest Rate

interest_df = pd.read_csv(Path(r'/Users/tarang/Downloads/Interest_Rate_2.csv'), index_col='Combined',infer_datetime_format=True, parse_dates=True)
interest_df.head()
# Out:
#             Upper Range
# Combined
# 2015-12-01          0.5
# 2016-01-01          0.5
# 2016-02-01          0.5
# 2016-03-01          0.5
# 2016-04-01          0.5

# %%
#Interest PCT CHANGE
interest_pct = interest_df.pct_change().dropna()
interest_pct.head()
# Out:
#             Upper Range
# Combined
# 2016-01-01          0.0
# 2016-02-01          0.0
# 2016-03-01          0.0
# 2016-04-01          0.0
# 2016-05-01          0.0

# %%
interest_pct.hvplot(fig_size= ('30','10'),xlabel="Month", 
    ylabel="Interest Rate Change", 
    rot=70)
# Out:
# WARNING:param.main: fig_size option not found for line plot; similar options include: ['fontsize']
# :Curve   [Combined]   (Upper Range)

# %%
#Interest vs beta 
ax = rolling_google_beta.plot(figsize=(20, 10), title="Rolling 30-Day Beta of Google vs Interest")
interest_pct.plot(ax=ax)

ax.legend(["GOOGLE", "INTEREST CHANGE"])
