# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import hvplot.pandas
from MCForecastTools import MCSimulation

# %%
file_path = Path("/Users/tarang/Downloads/properties.csv")
df = pd.read_csv("/Users/tarang/Downloads/properties.csv")
df.head(10)
# Out:
#    Unnamed: 0                                  Address           AreaName  \
# 0           0              86 Waterford Dr Toronto, ON           Richview
# 1           1         #80 - 100 BEDDOE DR Hamilton, ON     Chedoke Park B
# 2           2           213 Bowman Street Hamilton, ON  Ainslie Wood East
# 3           3             102 NEIL Avenue Hamilton, ON          Greenford
# 4           6          #1409 - 230 King St Toronto, ON           Downtown
# 5           7        254A Monarch Park Ave Toronto, ON      Old East York
# 6           8             532 Caledonia Rd Toronto, ON           Fairbank
# 7           9           11 REBECCA Street Hamilton, ON   Central Hamilton
# 8          10         617 BRIGADOON Drive Hamilton, ON            Gourley
# 9          12  51 - 255 MOUNT ALBION Road Hamilton, ON           Red Hill
#
#    Price ($)        lat        lng
# 0     999888  43.679882 -79.544266
# 1     399900  43.250000 -79.904396
# 2     479000  43.251690 -79.919357
# ...

# %%
df = df.set_index('Unnamed: 0')

# %%
df.head(10)
# Out:
#                                             Address           AreaName  \
# Unnamed: 0
# 0                       86 Waterford Dr Toronto, ON           Richview
# 1                  #80 - 100 BEDDOE DR Hamilton, ON     Chedoke Park B
# 2                    213 Bowman Street Hamilton, ON  Ainslie Wood East
# 3                      102 NEIL Avenue Hamilton, ON          Greenford
# 6                   #1409 - 230 King St Toronto, ON           Downtown
# 7                 254A Monarch Park Ave Toronto, ON      Old East York
# 8                      532 Caledonia Rd Toronto, ON           Fairbank
# 9                    11 REBECCA Street Hamilton, ON   Central Hamilton
# 10                 617 BRIGADOON Drive Hamilton, ON            Gourley
# 12          51 - 255 MOUNT ALBION Road Hamilton, ON           Red Hill
#
#             Price ($)        lat        lng
# Unnamed: 0
# 0              999888  43.679882 -79.544266
# 1              399900  43.250000 -79.904396
# ...

# %%
# Group by Area Name
df_area = df.groupby(by=["AreaName"], dropna=True).sum()

# %%
# Highest Area by price
df_area.sort_values('Price ($)', ascending=False)
# Out:
#                                    Price ($)           lat           lng
# AreaName
# Downtown                           490318877  36228.004025 -65883.891654
# Mississauga                        461821768  32782.615331 -59898.453551
# Oakville                           428404339  13299.593407 -24385.118614
# Midtown Toronto                    413403776  13150.703875 -23899.739424
# Richmond Hill                      373506211  14700.781777 -26610.139044
# ...                                      ...           ...           ...
# Manitowaning                           14999     45.739494    -81.807777
# Bishop Hellmuth Heritage District       5650    128.988876   -243.754485
# Trillium Industrial Park                3800     43.414257    -80.449989
# North End West                             0     43.269379    -79.865402
# Port Lands                                 0     43.647285    -79.351509
#
# [1119 rows x 3 columns]

# %%
#20 Highest
df_20 = df_area['Price ($)'].nlargest(20)
df_20
# Out:
# AreaName
# Downtown           490318877
# Mississauga        461821768
# Oakville           428404339
# Midtown Toronto    413403776
# Richmond Hill      373506211
# Burlington         269009467
# Brampton           236031607
# Waterloo           231351351
# Willowdale         227066114
# Caledon            180962425
# Niagara Falls      165053708
# Woodbridge         122043750
# Erin Mills         118855963
# Stoney Creek       114139933
# Huntsville         114041863
# Newtonbrook        109476356
# Belleville         107558777
# York Mills         106469809
# Bridle Path        106283000
# Barrie             100777578
# Name: Price ($), dtype: int64

# %%
df_20.hvplot(kind='line', figsize='20')
# Out:
# :Curve   [AreaName]   (Price ($))

# %%
df_20.hvplot(kind='barh')
# Out:
# :Bars   [AreaName]   (Price ($))
